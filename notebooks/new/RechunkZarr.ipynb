# %% [markdown]
# # Modify the chunks for an existing file

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import podpac
from podpac import Node
from podpac import alglib
import traitlets as tl
import logging
import time
import inspect
logger = logging.getLogger('podpac')
logger.setLevel(logging.INFO)

# %%
SRC_FILE = r's3://podpac-drought-monitor-s3/SMAP_CATS_2.zarr'
DST_FILE = r's3://podpac-drought-monitor-s3/SMAP_CATS_CHUNKED.zarr'
CHUNKS = {'lat': 256, 'lon': 256, 'time': 16}

# %%
settings = {
    "FUNCTION_NAME": "podpac-drought-monitor-lambda-compute-stats",
    "S3_BUCKET_NAME": "podpac-drought-monitor-s3",
    "FUNCTION_ROLE_NAME": "podpac-drought-monitor-role",
    "MULTITHREADING": True,
    "N_THREADS": 64,
    "AWS_ACCESS_KEY_ID": podpac.settings["AWS_ACCESS_KEY_ID"],
    "AWS_SECRET_ACCESS_KEY": podpac.settings["AWS_SECRET_ACCESS_KEY"],
    "AWS_REGION_NAME": podpac.settings["AWS_REGION_NAME"],
    "AWS_BUDGET_AMOUNT": 100,
    "AWS_BUDGET_EMAIL": podpac.settings["AWS_BUDGET_EMAIL"],
    "FUNCTION_DEPENDENCIES_KEY": "podpac_deps.zip",
}
podpac.settings.update(settings)
# settings

# %%
N_WORKERS = 25

# %%
node = podpac.data.Zarr(
    source=SRC_FILE,
    time_key='time',
    lat_key='lat',
    lon_key='lon',
    skip_validation=True,
)
# node

# %%
coords_mp = node.coordinates#.select({"lat": [], "lon": []})
coords_mp
# Out:
# Coordinates (EPSG:4326)
# 	lat: ArrayCoordinates1d(lat): Bounds[-84.65642547607422, 84.65641784667969], N[1624], ctype['midpoint']
# 	lon: ArrayCoordinates1d(lon): Bounds[-179.95314025878906, 179.95314025878906], N[3856], ctype['midpoint']
# 	time: ArrayCoordinates1d(time): Bounds[1.0, 366.0], N[366], ctype['midpoint']

# %%
node_p = podpac.managers.Lambda(
    source=node,
    eval_settings=settings,
    eval_timeout=1.25
)

# %%
node_p.get_budget()
node_p.describe()
# Out:
# Lambda Node (staged)
#     Function
#         Name: podpac-drought-monitor-lambda-compute-stats
#         Description: PODPAC Lambda Function (https://podpac.org)
#         ARN: None
#         Triggers: ['eval']
#         Handler: handler.handler
#         Environment Variables: {}
#         Timeout: 600 seconds
#         Memory: 2048 MB
#         Tags: {}
#         Source Dist: s3://podpac-dist/dev/podpac_dist.zip
#         Source Dependencies: s3://podpac-dist/dev/podpac_deps.zip
#         Last Modified: None
#         Version: None
#         Restrict Evaluation: []
#
#     S3
#         Bucket: podpac-drought-monitor-s3
#         Tags: {}
#         Input Folder: input/
#         Output Folder: output/
#
#     Role
#         Name: podpac-drought-monitor-role
#         Description: PODPAC Lambda Role
#         ARN: None
#         Policy Document: {'Version': '2012-10-17', 'Statement': [{'Effect': 'Allow', 'Action': ['s3:PutObject', 's3:GetObject', 's3:DeleteObject', 's3:ReplicateObject', 's3:ListBucket', 's3:ListMultipartUploadParts', 's3:ListBucketByTags', 's3:GetBucketTagging', 's3:ListBucketVersions', 's3:AbortMultipartUpload', 's3:GetObjectTagging', 's3:ListBucketMultipartUploads', 's3:GetBucketLocation', 's3:GetObjectVersion'], 'Resource': ['arn:aws:s3:::podpac-drought-monitor-s3/*']}]}
#         Policy ARNs: ['arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole']
#         Assume Policy Document: {'Version': '2012-10-17', 'Statement': [{'Effect': 'Allow', 'Principal': {'Service': 'lambda.amazonaws.com'}, 'Action': 'sts:AssumeRole'}]}
#         Tags: {}
#
#
#
#
#     Budget
#         Name: podpac-drought-monitor-lambda-compute-stats-budget
#         Amount: 500.0
#         Currency: USD
#         E-mail: mpu@creare.com
#         Spent: 1252.847 USD

# %%
node_mp = podpac.core.managers.parallel.ParallelAsyncOutputZarr(
    source=node_p, 
    number_of_workers=N_WORKERS,
    chunks=CHUNKS,
    zarr_file=DST_FILE, init_file_mode='a',
    skip_existing=False,  # Set this to True on subsequent runs
    list_dir=False,  # Set this to True on subsequent runs
    aws_config_kwargs=dict(max_pool_connections=N_WORKERS*10),  # This is needed to avoid a warning about the number of open connections
    start_i = 0  # I was developing the software as I was doing this computation, so I made improvements along the way and did not want to start over
)
node_mp
# Out:
# <ParallelAsyncOutputZarr(source=Lambda (staged)
# 	Name: podpac-drought-monitor-lambda-compute-stats
# 	Source: Zarr
# 	Bucket: podpac-drought-monitor-s3
# 	Triggers: ['eval']
# 	Role: podpac-drought-monitor-role
# , number_of_workers=25, chunks={'lat': 256, 'lon': 256, 'time': 12})>

# %%
# time.sleep(3600 * 2)
o_mp = node_mp.eval(coords_mp)
# Out:
# INFO:podpac.core.managers.parallel:Submitting source 7
# INFO:podpac.core.managers.parallel:Submitting source 21
# INFO:podpac.core.managers.parallel:Submitting source 10
# INFO:podpac.core.managers.parallel:Submitting source 3
# INFO:podpac.core.managers.parallel:Submitting source 19
# INFO:podpac.core.managers.parallel:Submitting source 23
# INFO:podpac.core.managers.parallel:Submitting source 17
# INFO:podpac.core.managers.parallel:Submitting source 11
# INFO:podpac.core.managers.parallel:Submitting source 14
# INFO:podpac.core.managers.parallel:Submitting source 20
# INFO:podpac.core.managers.parallel:Submitting source 6
# INFO:podpac.core.managers.parallel:Submitting source 5
# INFO:podpac.core.managers.parallel:Added all chunks to worker pool. Now waiting for results.
# INFO:podpac.core.managers.parallel:(0:00:00): Waiting for results: 1 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 9
# INFO:podpac.core.managers.parallel:Submitting source 24
# INFO:podpac.core.managers.parallel:Submitting source 15
# INFO:podpac.core.managers.parallel:Submitting source 4
# INFO:podpac.core.managers.parallel:Submitting source 2
# INFO:podpac.core.managers.parallel:Submitting source 13
# INFO:podpac.core.managers.parallel:Submitting source 12
# INFO:podpac.core.managers.parallel:Submitting source 8
# INFO:podpac.core.managers.parallel:Submitting source 22
# INFO:podpac.core.managers.parallel:Submitting source 18
# INFO:podpac.core.managers.parallel:Submitting source 16
# INFO:podpac.core.managers.parallel:Submitting source 1
# INFO:podpac.core.managers.parallel:Submitting source 0
# INFO:podpac.core.managers.parallel:(2.714484453201294) Finished result: 1 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.724000): Waiting for results: 2 / 3472
# INFO:podpac.core.managers.parallel:(2.7244648933410645) Finished result: 2 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.725000): Waiting for results: 3 / 3472
# INFO:podpac.core.managers.parallel:(2.7264630794525146) Finished result: 3 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.728000): Waiting for results: 4 / 3472
# INFO:podpac.core.managers.parallel:(2.729461669921875) Finished result: 4 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.733000): Waiting for results: 5 / 3472
# INFO:podpac.core.managers.parallel:(2.73445987701416) Finished result: 5 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.734000): Waiting for results: 6 / 3472
# INFO:podpac.core.managers.parallel:(2.7354576587677) Finished result: 6 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.735000): Waiting for results: 7 / 3472
# INFO:podpac.core.managers.parallel:(2.7364609241485596) Finished result: 7 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.736000): Waiting for results: 8 / 3472
# INFO:podpac.core.managers.parallel:(2.737456798553467) Finished result: 8 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.738000): Waiting for results: 9 / 3472
# INFO:podpac.core.managers.parallel:(2.7384562492370605) Finished result: 9 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.739000): Waiting for results: 10 / 3472
# INFO:podpac.core.managers.parallel:(2.740455150604248) Finished result: 10 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.740000): Waiting for results: 11 / 3472
# INFO:podpac.core.managers.parallel:(2.741455078125) Finished result: 11 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.742000): Waiting for results: 12 / 3472
# INFO:podpac.core.managers.parallel:(2.7424561977386475) Finished result: 12 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.743000): Waiting for results: 13 / 3472
# INFO:podpac.core.managers.parallel:(2.7434535026550293) Finished result: 13 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.744000): Waiting for results: 14 / 3472
# INFO:podpac.core.managers.parallel:(2.7454535961151123) Finished result: 14 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.745000): Waiting for results: 15 / 3472
# INFO:podpac.core.managers.parallel:(2.7464630603790283) Finished result: 15 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.747000): Waiting for results: 16 / 3472
# INFO:podpac.core.managers.parallel:(2.747450590133667) Finished result: 16 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.748000): Waiting for results: 17 / 3472
# INFO:podpac.core.managers.parallel:(2.7484512329101562) Finished result: 17 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.749000): Waiting for results: 18 / 3472
# INFO:podpac.core.managers.parallel:(2.7494499683380127) Finished result: 18 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.750000): Waiting for results: 19 / 3472
# INFO:podpac.core.managers.parallel:(2.7514491081237793) Finished result: 19 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.751000): Waiting for results: 20 / 3472
# INFO:podpac.core.managers.parallel:(2.752448081970215) Finished result: 20 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.753000): Waiting for results: 21 / 3472
# INFO:podpac.core.managers.parallel:(2.7534475326538086) Finished result: 21 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.754000): Waiting for results: 22 / 3472
# INFO:podpac.core.managers.parallel:(2.7544469833374023) Finished result: 22 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.755000): Waiting for results: 23 / 3472
# INFO:podpac.core.managers.parallel:(2.7554476261138916) Finished result: 23 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.756000): Waiting for results: 24 / 3472
# INFO:podpac.core.managers.parallel:(2.7574453353881836) Finished result: 24 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.757000): Waiting for results: 25 / 3472
# INFO:podpac.core.managers.parallel:(2.7584447860717773) Finished result: 25 / 3472
# INFO:podpac.core.managers.parallel:(0:00:02.759000): Waiting for results: 26 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 45
# INFO:podpac.core.managers.parallel:Submitting source 46
# INFO:podpac.core.managers.parallel:Submitting source 48
# INFO:podpac.core.managers.parallel:Submitting source 28
# INFO:podpac.core.managers.parallel:Submitting source 25
# INFO:podpac.core.managers.parallel:Submitting source 30
# INFO:podpac.core.managers.parallel:Submitting source 35
# INFO:podpac.core.managers.parallel:Submitting source 31
# INFO:podpac.core.managers.parallel:Submitting source 40
# INFO:podpac.core.managers.parallel:Submitting source 37
# INFO:podpac.core.managers.parallel:Submitting source 36
# INFO:podpac.core.managers.parallel:Submitting source 34
# INFO:podpac.core.managers.parallel:(6.532199859619141) Finished result: 26 / 3472
# INFO:podpac.core.managers.parallel:(0:00:06.710000): Waiting for results: 27 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 38
# INFO:podpac.core.managers.parallel:Submitting source 42
# INFO:podpac.core.managers.parallel:Submitting source 44
# INFO:podpac.core.managers.parallel:Submitting source 41
# INFO:podpac.core.managers.parallel:Submitting source 43
# INFO:podpac.core.managers.parallel:Submitting source 33
# INFO:podpac.core.managers.parallel:Submitting source 32
# INFO:podpac.core.managers.parallel:Submitting source 39
# INFO:podpac.core.managers.parallel:Submitting source 49
# INFO:podpac.core.managers.parallel:Submitting source 27
# INFO:podpac.core.managers.parallel:Submitting source 47
# INFO:podpac.core.managers.parallel:Submitting source 29
# INFO:podpac.core.managers.parallel:Submitting source 26
# INFO:podpac.core.managers.parallel:(12.914531469345093) Finished result: 27 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.926000): Waiting for results: 28 / 3472
# INFO:podpac.core.managers.parallel:(12.926521062850952) Finished result: 28 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.927000): Waiting for results: 29 / 3472
# INFO:podpac.core.managers.parallel:(12.930503368377686) Finished result: 29 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.931000): Waiting for results: 30 / 3472
# INFO:podpac.core.managers.parallel:(12.931503057479858) Finished result: 30 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.937000): Waiting for results: 31 / 3472
# INFO:podpac.core.managers.parallel:(12.937516212463379) Finished result: 31 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.938000): Waiting for results: 32 / 3472
# INFO:podpac.core.managers.parallel:(12.939510583877563) Finished result: 32 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.939000): Waiting for results: 33 / 3472
# INFO:podpac.core.managers.parallel:(12.940498352050781) Finished result: 33 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.940000): Waiting for results: 34 / 3472
# INFO:podpac.core.managers.parallel:(12.94149661064148) Finished result: 34 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.942000): Waiting for results: 35 / 3472
# INFO:podpac.core.managers.parallel:(12.942496061325073) Finished result: 35 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.943000): Waiting for results: 36 / 3472
# INFO:podpac.core.managers.parallel:(12.94449520111084) Finished result: 36 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.944000): Waiting for results: 37 / 3472
# INFO:podpac.core.managers.parallel:(12.945494890213013) Finished result: 37 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.946000): Waiting for results: 38 / 3472
# INFO:podpac.core.managers.parallel:(12.946494102478027) Finished result: 38 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.947000): Waiting for results: 39 / 3472
# INFO:podpac.core.managers.parallel:(12.948493957519531) Finished result: 39 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.948000): Waiting for results: 40 / 3472
# INFO:podpac.core.managers.parallel:(12.949494361877441) Finished result: 40 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.949000): Waiting for results: 41 / 3472
# INFO:podpac.core.managers.parallel:(12.950491905212402) Finished result: 41 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.950000): Waiting for results: 42 / 3472
# INFO:podpac.core.managers.parallel:(12.95149302482605) Finished result: 42 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.952000): Waiting for results: 43 / 3472
# INFO:podpac.core.managers.parallel:(12.953491687774658) Finished result: 43 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.954000): Waiting for results: 44 / 3472
# INFO:podpac.core.managers.parallel:(12.954490423202515) Finished result: 44 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.955000): Waiting for results: 45 / 3472
# INFO:podpac.core.managers.parallel:(12.955489158630371) Finished result: 45 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.956000): Waiting for results: 46 / 3472
# INFO:podpac.core.managers.parallel:(12.957507133483887) Finished result: 46 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.957000): Waiting for results: 47 / 3472
# INFO:podpac.core.managers.parallel:(12.958487272262573) Finished result: 47 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.958000): Waiting for results: 48 / 3472
# INFO:podpac.core.managers.parallel:(12.959486484527588) Finished result: 48 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.959000): Waiting for results: 49 / 3472
# INFO:podpac.core.managers.parallel:(12.960485935211182) Finished result: 49 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.961000): Waiting for results: 50 / 3472
# INFO:podpac.core.managers.parallel:(12.962485313415527) Finished result: 50 / 3472
# INFO:podpac.core.managers.parallel:(0:00:12.962000): Waiting for results: 51 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 51
# INFO:podpac.core.managers.parallel:Submitting source 58
# INFO:podpac.core.managers.parallel:Submitting source 56
# INFO:podpac.core.managers.parallel:Submitting source 52
# INFO:podpac.core.managers.parallel:Submitting source 63
# INFO:podpac.core.managers.parallel:Submitting source 65
# INFO:podpac.core.managers.parallel:Submitting source 50
# INFO:podpac.core.managers.parallel:Submitting source 53
# INFO:podpac.core.managers.parallel:(17.815738439559937) Finished result: 51 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 55
# INFO:podpac.core.managers.parallel:(0:00:17.838000): Waiting for results: 52 / 3472
# INFO:podpac.core.managers.parallel:(17.865710258483887) Finished result: 52 / 3472
# INFO:podpac.core.managers.parallel:(0:00:17.866000): Waiting for results: 53 / 3472
# INFO:podpac.core.managers.parallel:(18.15456247329712) Finished result: 53 / 3472
# INFO:podpac.core.managers.parallel:(0:00:18.155000): Waiting for results: 54 / 3472
# INFO:podpac.core.managers.parallel:(18.16154456138611) Finished result: 54 / 3472
# INFO:podpac.core.managers.parallel:(0:00:18.162000): Waiting for results: 55 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 68
# INFO:podpac.core.managers.parallel:Submitting source 67
# INFO:podpac.core.managers.parallel:Submitting source 59
# INFO:podpac.core.managers.parallel:Submitting source 61
# INFO:podpac.core.managers.parallel:Submitting source 60
# INFO:podpac.core.managers.parallel:Submitting source 57
# INFO:podpac.core.managers.parallel:Submitting source 74
# INFO:podpac.core.managers.parallel:Submitting source 71
# INFO:podpac.core.managers.parallel:Submitting source 66
# INFO:podpac.core.managers.parallel:Submitting source 64
# INFO:podpac.core.managers.parallel:Submitting source 70
# INFO:podpac.core.managers.parallel:Submitting source 69
# INFO:podpac.core.managers.parallel:Submitting source 72
# INFO:podpac.core.managers.parallel:Submitting source 62
# INFO:podpac.core.managers.parallel:Submitting source 80
# INFO:podpac.core.managers.parallel:Submitting source 85
# INFO:podpac.core.managers.parallel:Submitting source 78
# INFO:podpac.core.managers.parallel:Submitting source 73
# INFO:podpac.core.managers.parallel:Submitting source 54
# INFO:podpac.core.managers.parallel:(28.95262622833252) Finished result: 55 / 3472
# INFO:podpac.core.managers.parallel:(0:00:28.964000): Waiting for results: 56 / 3472
# INFO:podpac.core.managers.parallel:(28.97161555290222) Finished result: 56 / 3472
# INFO:podpac.core.managers.parallel:(0:00:28.974000): Waiting for results: 57 / 3472
# INFO:podpac.core.managers.parallel:(28.97561001777649) Finished result: 57 / 3472
# INFO:podpac.core.managers.parallel:(0:00:28.979000): Waiting for results: 58 / 3472
# INFO:podpac.core.managers.parallel:(28.980607986450195) Finished result: 58 / 3472
# INFO:podpac.core.managers.parallel:(0:00:28.981000): Waiting for results: 59 / 3472
# INFO:podpac.core.managers.parallel:(28.992620706558228) Finished result: 59 / 3472
# INFO:podpac.core.managers.parallel:(0:00:28.993000): Waiting for results: 60 / 3472
# INFO:podpac.core.managers.parallel:(28.994598865509033) Finished result: 60 / 3472
# INFO:podpac.core.managers.parallel:(0:00:28.995000): Waiting for results: 61 / 3472
# INFO:podpac.core.managers.parallel:(28.996596813201904) Finished result: 61 / 3472
# INFO:podpac.core.managers.parallel:(0:00:28.996000): Waiting for results: 62 / 3472
# INFO:podpac.core.managers.parallel:(28.997596263885498) Finished result: 62 / 3472
# INFO:podpac.core.managers.parallel:(0:00:28.997000): Waiting for results: 63 / 3472
# INFO:podpac.core.managers.parallel:(28.99859595298767) Finished result: 63 / 3472
# INFO:podpac.core.managers.parallel:(0:00:28.999000): Waiting for results: 64 / 3472
# INFO:podpac.core.managers.parallel:(28.999595403671265) Finished result: 64 / 3472
# INFO:podpac.core.managers.parallel:(0:00:29): Waiting for results: 65 / 3472
# INFO:podpac.core.managers.parallel:(29.00159788131714) Finished result: 65 / 3472
# INFO:podpac.core.managers.parallel:(0:00:29.001000): Waiting for results: 66 / 3472
# INFO:podpac.core.managers.parallel:(29.002593755722046) Finished result: 66 / 3472
# INFO:podpac.core.managers.parallel:(0:00:29.003000): Waiting for results: 67 / 3472
# INFO:podpac.core.managers.parallel:(29.00359272956848) Finished result: 67 / 3472
# INFO:podpac.core.managers.parallel:(0:00:29.004000): Waiting for results: 68 / 3472
# INFO:podpac.core.managers.parallel:(29.005593299865723) Finished result: 68 / 3472
# INFO:podpac.core.managers.parallel:(0:00:29.005000): Waiting for results: 69 / 3472
# INFO:podpac.core.managers.parallel:(29.006592512130737) Finished result: 69 / 3472
# INFO:podpac.core.managers.parallel:(0:00:29.007000): Waiting for results: 70 / 3472
# INFO:podpac.core.managers.parallel:(29.007590770721436) Finished result: 70 / 3472
# INFO:podpac.core.managers.parallel:(0:00:29.008000): Waiting for results: 71 / 3472
# INFO:podpac.core.managers.parallel:(29.009591341018677) Finished result: 71 / 3472
# INFO:podpac.core.managers.parallel:(0:00:29.009000): Waiting for results: 72 / 3472
# INFO:podpac.core.managers.parallel:(29.01059079170227) Finished result: 72 / 3472
# INFO:podpac.core.managers.parallel:(0:00:29.011000): Waiting for results: 73 / 3472
# INFO:podpac.core.managers.parallel:(29.011590719223022) Finished result: 73 / 3472
# INFO:podpac.core.managers.parallel:(0:00:29.012000): Waiting for results: 74 / 3472
# INFO:podpac.core.managers.parallel:(29.013587951660156) Finished result: 74 / 3472
# INFO:podpac.core.managers.parallel:(0:00:29.014000): Waiting for results: 75 / 3472
# INFO:podpac.core.managers.parallel:(29.014586687088013) Finished result: 75 / 3472
# INFO:podpac.core.managers.parallel:(0:00:29.015000): Waiting for results: 76 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 84
# INFO:podpac.core.managers.parallel:Submitting source 82
# INFO:podpac.core.managers.parallel:Submitting source 83
# INFO:podpac.core.managers.parallel:Submitting source 81
# INFO:podpac.core.managers.parallel:Submitting source 89
# INFO:podpac.core.managers.parallel:Submitting source 94
# INFO:podpac.core.managers.parallel:Submitting source 93
# INFO:podpac.core.managers.parallel:Submitting source 88
# INFO:podpac.core.managers.parallel:Submitting source 92
# INFO:podpac.core.managers.parallel:Submitting source 90
# INFO:podpac.core.managers.parallel:Submitting source 91
# INFO:podpac.core.managers.parallel:Submitting source 105
# INFO:podpac.core.managers.parallel:Submitting source 98
# INFO:podpac.core.managers.parallel:Submitting source 96
# INFO:podpac.core.managers.parallel:Submitting source 101
# INFO:podpac.core.managers.parallel:Submitting source 95
# INFO:podpac.core.managers.parallel:Submitting source 97
# INFO:podpac.core.managers.parallel:Submitting source 109
# INFO:podpac.core.managers.parallel:Submitting source 112
# INFO:podpac.core.managers.parallel:Submitting source 103
# INFO:podpac.core.managers.parallel:Submitting source 99
# INFO:podpac.core.managers.parallel:Submitting source 113
# INFO:podpac.core.managers.parallel:Submitting source 115
# INFO:podpac.core.managers.parallel:Submitting source 107
# INFO:podpac.core.managers.parallel:Submitting source 111
# INFO:podpac.core.managers.parallel:Submitting source 118
# INFO:podpac.core.managers.parallel:Submitting source 108
# INFO:podpac.core.managers.parallel:Submitting source 114
# INFO:podpac.core.managers.parallel:Submitting source 106
# INFO:podpac.core.managers.parallel:Submitting source 100
# INFO:podpac.core.managers.parallel:Submitting source 102
# INFO:podpac.core.managers.parallel:Submitting source 120
# INFO:podpac.core.managers.parallel:Submitting source 116
# INFO:podpac.core.managers.parallel:Submitting source 75
# INFO:podpac.core.managers.parallel:(47.54889154434204) Finished result: 76 / 3472
# INFO:podpac.core.managers.parallel:(0:00:47.571000): Waiting for results: 77 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 123
# INFO:podpac.core.managers.parallel:Submitting source 86
# INFO:podpac.core.managers.parallel:Submitting source 122
# INFO:podpac.core.managers.parallel:Submitting source 125
# INFO:podpac.core.managers.parallel:Submitting source 129
# INFO:podpac.core.managers.parallel:Submitting source 87
# INFO:podpac.core.managers.parallel:Submitting source 104
# INFO:podpac.core.managers.parallel:Submitting source 110
# INFO:podpac.core.managers.parallel:Submitting source 124
# INFO:podpac.core.managers.parallel:Submitting source 117
# INFO:podpac.core.managers.parallel:Submitting source 126
# INFO:podpac.core.managers.parallel:Submitting source 136
# INFO:podpac.core.managers.parallel:Submitting source 132
# INFO:podpac.core.managers.parallel:Submitting source 135
# INFO:podpac.core.managers.parallel:Submitting source 143
# INFO:podpac.core.managers.parallel:Submitting source 133
# INFO:podpac.core.managers.parallel:Submitting source 134
# INFO:podpac.core.managers.parallel:Submitting source 128
# INFO:podpac.core.managers.parallel:Submitting source 145
# INFO:podpac.core.managers.parallel:Submitting source 141
# INFO:podpac.core.managers.parallel:Submitting source 142
# INFO:podpac.core.managers.parallel:Submitting source 144
# INFO:podpac.core.managers.parallel:Submitting source 121
# INFO:podpac.core.managers.parallel:Submitting source 131
# INFO:podpac.core.managers.parallel:Submitting source 147
# INFO:podpac.core.managers.parallel:Submitting source 137
# INFO:podpac.core.managers.parallel:Submitting source 127
# INFO:podpac.core.managers.parallel:Submitting source 138
# INFO:podpac.core.managers.parallel:Submitting source 146
# INFO:podpac.core.managers.parallel:Submitting source 152
# INFO:podpac.core.managers.parallel:Submitting source 139
# INFO:podpac.core.managers.parallel:Submitting source 148
# INFO:podpac.core.managers.parallel:Submitting source 153
# INFO:podpac.core.managers.parallel:Submitting source 150
# INFO:podpac.core.managers.parallel:Submitting source 156
# INFO:podpac.core.managers.parallel:Submitting source 155
# INFO:podpac.core.managers.parallel:Submitting source 163
# INFO:podpac.core.managers.parallel:Submitting source 164
# INFO:podpac.core.managers.parallel:Submitting source 119
# INFO:podpac.core.managers.parallel:Submitting source 161
# INFO:podpac.core.managers.parallel:Submitting source 160
# INFO:podpac.core.managers.parallel:Submitting source 159
# INFO:podpac.core.managers.parallel:Submitting source 167
# INFO:podpac.core.managers.parallel:Submitting source 162
# INFO:podpac.core.managers.parallel:Submitting source 158
# INFO:podpac.core.managers.parallel:Submitting source 77
# INFO:podpac.core.managers.parallel:Submitting source 169
# INFO:podpac.core.managers.parallel:Submitting source 79
# INFO:podpac.core.managers.parallel:Submitting source 168
# INFO:podpac.core.managers.parallel:Submitting source 172
# INFO:podpac.core.managers.parallel:Submitting source 165
# INFO:podpac.core.managers.parallel:Submitting source 166
# INFO:podpac.core.managers.parallel:Submitting source 171
# INFO:podpac.core.managers.parallel:Submitting source 184
# INFO:podpac.core.managers.parallel:Submitting source 183
# INFO:podpac.core.managers.parallel:Submitting source 180
# INFO:podpac.core.managers.parallel:Submitting source 157
# INFO:podpac.core.managers.parallel:Submitting source 154
# INFO:podpac.core.managers.parallel:Submitting source 174
# INFO:podpac.core.managers.parallel:Submitting source 175
# INFO:podpac.core.managers.parallel:Submitting source 130
# INFO:podpac.core.managers.parallel:Submitting source 179
# INFO:podpac.core.managers.parallel:Submitting source 177
# INFO:podpac.core.managers.parallel:Submitting source 181
# INFO:podpac.core.managers.parallel:Submitting source 187
# INFO:podpac.core.managers.parallel:Submitting source 173
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# INFO:podpac.core.managers.parallel:Submitting source 192
# INFO:podpac.core.managers.parallel:Submitting source 189
# INFO:podpac.core.managers.parallel:Submitting source 193
# INFO:podpac.core.managers.parallel:Submitting source 188
# INFO:podpac.core.managers.parallel:Submitting source 197
# INFO:podpac.core.managers.parallel:Submitting source 199
# INFO:podpac.core.managers.parallel:Submitting source 198
# INFO:podpac.core.managers.parallel:Submitting source 140
# INFO:podpac.core.managers.parallel:Submitting source 194
# INFO:podpac.core.managers.parallel:Submitting source 196
# INFO:podpac.core.managers.parallel:Submitting source 149
# INFO:podpac.core.managers.parallel:Submitting source 195
# INFO:podpac.core.managers.parallel:Submitting source 201
# INFO:podpac.core.managers.parallel:Submitting source 200
# INFO:podpac.core.managers.parallel:Submitting source 151
# INFO:podpac.core.managers.parallel:Submitting source 203
# INFO:podpac.core.managers.parallel:Submitting source 204
# INFO:podpac.core.managers.parallel:Submitting source 206
# INFO:podpac.core.managers.parallel:Submitting source 205
# INFO:podpac.core.managers.parallel:Submitting source 190
# INFO:podpac.core.managers.parallel:Submitting source 207
# INFO:podpac.core.managers.parallel:Submitting source 191
# INFO:podpac.core.managers.parallel:Submitting source 209
# INFO:podpac.core.managers.parallel:Submitting source 208
# INFO:podpac.core.managers.parallel:Submitting source 213
# INFO:podpac.core.managers.parallel:Submitting source 212
# INFO:podpac.core.managers.parallel:Submitting source 214
# INFO:podpac.core.managers.parallel:Submitting source 217
# INFO:podpac.core.managers.parallel:Submitting source 215
# INFO:podpac.core.managers.parallel:Submitting source 185
# INFO:podpac.core.managers.parallel:Submitting source 225
# INFO:podpac.core.managers.parallel:Submitting source 226
# INFO:podpac.core.managers.parallel:Submitting source 222
# INFO:podpac.core.managers.parallel:Submitting source 176
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# INFO:podpac.core.managers.parallel:Submitting source 216
# INFO:podpac.core.managers.parallel:Submitting source 230
# INFO:podpac.core.managers.parallel:Submitting source 228
# INFO:podpac.core.managers.parallel:Submitting source 231
# INFO:podpac.core.managers.parallel:Submitting source 233
# INFO:podpac.core.managers.parallel:Submitting source 229
# INFO:podpac.core.managers.parallel:Submitting source 236
# INFO:podpac.core.managers.parallel:Submitting source 234
# INFO:podpac.core.managers.parallel:Submitting source 235
# INFO:podpac.core.managers.parallel:Submitting source 237
# INFO:podpac.core.managers.parallel:Submitting source 232
# INFO:podpac.core.managers.parallel:Submitting source 218
# INFO:podpac.core.managers.parallel:Submitting source 248
# INFO:podpac.core.managers.parallel:Submitting source 244
# INFO:podpac.core.managers.parallel:Submitting source 243
# INFO:podpac.core.managers.parallel:Submitting source 250
# INFO:podpac.core.managers.parallel:Submitting source 249
# INFO:podpac.core.managers.parallel:Submitting source 251
# INFO:podpac.core.managers.parallel:Submitting source 202
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# INFO:podpac.core.managers.parallel:Submitting source 254
# INFO:podpac.core.managers.parallel:Submitting source 253
# INFO:podpac.core.managers.parallel:Submitting source 258
# INFO:podpac.core.managers.parallel:Submitting source 252
# INFO:podpac.core.managers.parallel:Submitting source 255
# INFO:podpac.core.managers.parallel:Submitting source 261
# INFO:podpac.core.managers.parallel:Submitting source 260
# INFO:podpac.core.managers.parallel:Submitting source 262
# INFO:podpac.core.managers.parallel:Submitting source 263
# INFO:podpac.core.managers.parallel:Submitting source 221
# INFO:podpac.core.managers.parallel:Submitting source 241
# INFO:podpac.core.managers.parallel:Submitting source 245
# INFO:podpac.core.managers.parallel:Submitting source 242
# INFO:podpac.core.managers.parallel:Submitting source 266
# INFO:podpac.core.managers.parallel:Submitting source 265
# INFO:podpac.core.managers.parallel:Submitting source 219
# INFO:podpac.core.managers.parallel:Submitting source 220
# INFO:podpac.core.managers.parallel:Submitting source 264
# INFO:podpac.core.managers.parallel:Submitting source 268
# INFO:podpac.core.managers.parallel:Submitting source 267
# INFO:podpac.core.managers.parallel:Submitting source 223
# INFO:podpac.core.managers.parallel:Submitting source 227
# INFO:podpac.core.managers.parallel:Submitting source 274
# INFO:podpac.core.managers.parallel:Submitting source 272
# INFO:podpac.core.managers.parallel:Submitting source 270
# INFO:podpac.core.managers.parallel:Submitting source 275
# INFO:podpac.core.managers.parallel:Submitting source 269
# INFO:podpac.core.managers.parallel:Submitting source 224
# INFO:podpac.core.managers.parallel:Submitting source 178
# INFO:podpac.core.managers.parallel:Submitting source 271
# INFO:podpac.core.managers.parallel:Submitting source 280
# INFO:podpac.core.managers.parallel:Submitting source 239
# INFO:podpac.core.managers.parallel:Submitting source 288
# INFO:podpac.core.managers.parallel:Submitting source 281
# INFO:podpac.core.managers.parallel:Submitting source 284
# INFO:podpac.core.managers.parallel:Submitting source 282
# INFO:podpac.core.managers.parallel:Submitting source 238
# INFO:podpac.core.managers.parallel:Submitting source 279
# INFO:podpac.core.managers.parallel:Submitting source 283
# INFO:podpac.core.managers.parallel:Submitting source 276
# INFO:podpac.core.managers.parallel:Submitting source 277
# INFO:podpac.core.managers.parallel:Submitting source 278
# INFO:podpac.core.managers.parallel:Submitting source 285
# INFO:podpac.core.managers.parallel:Submitting source 287
# INFO:podpac.core.managers.parallel:Submitting source 286
# INFO:podpac.core.managers.parallel:Submitting source 295
# INFO:podpac.core.managers.parallel:Submitting source 292
# INFO:podpac.core.managers.parallel:Submitting source 293
# INFO:podpac.core.managers.parallel:Submitting source 290
# INFO:podpac.core.managers.parallel:Submitting source 291
# INFO:podpac.core.managers.parallel:Submitting source 294
# INFO:podpac.core.managers.parallel:Submitting source 76
# INFO:podpac.core.managers.parallel:(131.73758697509766) Finished result: 77 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.755000): Waiting for results: 78 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 300
# INFO:podpac.core.managers.parallel:(131.75655126571655) Finished result: 78 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.777000): Waiting for results: 79 / 3472
# INFO:podpac.core.managers.parallel:(131.7795388698578) Finished result: 79 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.779000): Waiting for results: 80 / 3472
# INFO:podpac.core.managers.parallel:(131.78054022789001) Finished result: 80 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.787000): Waiting for results: 81 / 3472
# INFO:podpac.core.managers.parallel:(131.78953218460083) Finished result: 81 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.790000): Waiting for results: 82 / 3472
# INFO:podpac.core.managers.parallel:(131.79452991485596) Finished result: 82 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.795000): Waiting for results: 83 / 3472
# INFO:podpac.core.managers.parallel:(131.796528339386) Finished result: 83 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.796000): Waiting for results: 84 / 3472
# INFO:podpac.core.managers.parallel:(131.79752945899963) Finished result: 84 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.798000): Waiting for results: 85 / 3472
# INFO:podpac.core.managers.parallel:(131.79852843284607) Finished result: 85 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.799000): Waiting for results: 86 / 3472
# INFO:podpac.core.managers.parallel:(131.80052781105042) Finished result: 86 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.800000): Waiting for results: 87 / 3472
# INFO:podpac.core.managers.parallel:(131.80152583122253) Finished result: 87 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.802000): Waiting for results: 88 / 3472
# INFO:podpac.core.managers.parallel:(131.80252504348755) Finished result: 88 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.803000): Waiting for results: 89 / 3472
# INFO:podpac.core.managers.parallel:(131.80452513694763) Finished result: 89 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.804000): Waiting for results: 90 / 3472
# INFO:podpac.core.managers.parallel:(131.80552458763123) Finished result: 90 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.806000): Waiting for results: 91 / 3472
# INFO:podpac.core.managers.parallel:(131.80652403831482) Finished result: 91 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.807000): Waiting for results: 92 / 3472
# INFO:podpac.core.managers.parallel:(131.8085231781006) Finished result: 92 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.808000): Waiting for results: 93 / 3472
# INFO:podpac.core.managers.parallel:(131.80952286720276) Finished result: 93 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.810000): Waiting for results: 94 / 3472
# INFO:podpac.core.managers.parallel:(131.81152176856995) Finished result: 94 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.812000): Waiting for results: 95 / 3472
# INFO:podpac.core.managers.parallel:(131.8125298023224) Finished result: 95 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.813000): Waiting for results: 96 / 3472
# INFO:podpac.core.managers.parallel:(131.8145296573639) Finished result: 96 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.815000): Waiting for results: 97 / 3472
# INFO:podpac.core.managers.parallel:(131.81651711463928) Finished result: 97 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.816000): Waiting for results: 98 / 3472
# INFO:podpac.core.managers.parallel:(131.81751608848572) Finished result: 98 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.818000): Waiting for results: 99 / 3472
# INFO:podpac.core.managers.parallel:(131.81851601600647) Finished result: 99 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.819000): Waiting for results: 100 / 3472
# INFO:podpac.core.managers.parallel:(131.82051491737366) Finished result: 100 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.821000): Waiting for results: 101 / 3472
# INFO:podpac.core.managers.parallel:(131.82251381874084) Finished result: 101 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.822000): Waiting for results: 102 / 3472
# INFO:podpac.core.managers.parallel:(131.82351446151733) Finished result: 102 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.824000): Waiting for results: 103 / 3472
# INFO:podpac.core.managers.parallel:(131.8255205154419) Finished result: 103 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.825000): Waiting for results: 104 / 3472
# INFO:podpac.core.managers.parallel:(131.82651209831238) Finished result: 104 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.827000): Waiting for results: 105 / 3472
# INFO:podpac.core.managers.parallel:(131.8275122642517) Finished result: 105 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.828000): Waiting for results: 106 / 3472
# INFO:podpac.core.managers.parallel:(131.82950973510742) Finished result: 106 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.830000): Waiting for results: 107 / 3472
# INFO:podpac.core.managers.parallel:(131.8315088748932) Finished result: 107 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.831000): Waiting for results: 108 / 3472
# INFO:podpac.core.managers.parallel:(131.83250761032104) Finished result: 108 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.833000): Waiting for results: 109 / 3472
# INFO:podpac.core.managers.parallel:(131.83350729942322) Finished result: 109 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.834000): Waiting for results: 110 / 3472
# INFO:podpac.core.managers.parallel:(131.83550786972046) Finished result: 110 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.836000): Waiting for results: 111 / 3472
# INFO:podpac.core.managers.parallel:(131.837504863739) Finished result: 111 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.837000): Waiting for results: 112 / 3472
# INFO:podpac.core.managers.parallel:(131.8385045528412) Finished result: 112 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.839000): Waiting for results: 113 / 3472
# INFO:podpac.core.managers.parallel:(131.83950471878052) Finished result: 113 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.840000): Waiting for results: 114 / 3472
# INFO:podpac.core.managers.parallel:(131.84150290489197) Finished result: 114 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.841000): Waiting for results: 115 / 3472
# INFO:podpac.core.managers.parallel:(131.84250259399414) Finished result: 115 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.842000): Waiting for results: 116 / 3472
# INFO:podpac.core.managers.parallel:(131.84350180625916) Finished result: 116 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.844000): Waiting for results: 117 / 3472
# INFO:podpac.core.managers.parallel:(131.8445019721985) Finished result: 117 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.845000): Waiting for results: 118 / 3472
# INFO:podpac.core.managers.parallel:(131.84650182724) Finished result: 118 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.846000): Waiting for results: 119 / 3472
# INFO:podpac.core.managers.parallel:(131.84749937057495) Finished result: 119 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.848000): Waiting for results: 120 / 3472
# INFO:podpac.core.managers.parallel:(131.8494997024536) Finished result: 120 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.849000): Waiting for results: 121 / 3472
# INFO:podpac.core.managers.parallel:(131.85049772262573) Finished result: 121 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.851000): Waiting for results: 122 / 3472
# INFO:podpac.core.managers.parallel:(131.85149717330933) Finished result: 122 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.852000): Waiting for results: 123 / 3472
# INFO:podpac.core.managers.parallel:(131.85349655151367) Finished result: 123 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.853000): Waiting for results: 124 / 3472
# INFO:podpac.core.managers.parallel:(131.85449504852295) Finished result: 124 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.855000): Waiting for results: 125 / 3472
# INFO:podpac.core.managers.parallel:(131.8564944267273) Finished result: 125 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.857000): Waiting for results: 126 / 3472
# INFO:podpac.core.managers.parallel:(131.85749506950378) Finished result: 126 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.858000): Waiting for results: 127 / 3472
# INFO:podpac.core.managers.parallel:(131.85949540138245) Finished result: 127 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.859000): Waiting for results: 128 / 3472
# INFO:podpac.core.managers.parallel:(131.86049389839172) Finished result: 128 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.861000): Waiting for results: 129 / 3472
# INFO:podpac.core.managers.parallel:(131.86249160766602) Finished result: 129 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.863000): Waiting for results: 130 / 3472
# INFO:podpac.core.managers.parallel:(131.86448979377747) Finished result: 130 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.864000): Waiting for results: 131 / 3472
# INFO:podpac.core.managers.parallel:(131.86549067497253) Finished result: 131 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.866000): Waiting for results: 132 / 3472
# INFO:podpac.core.managers.parallel:(131.86748814582825) Finished result: 132 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.867000): Waiting for results: 133 / 3472
# INFO:podpac.core.managers.parallel:(131.86848902702332) Finished result: 133 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.869000): Waiting for results: 134 / 3472
# INFO:podpac.core.managers.parallel:(131.87048888206482) Finished result: 134 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.871000): Waiting for results: 135 / 3472
# INFO:podpac.core.managers.parallel:(131.87149596214294) Finished result: 135 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.872000): Waiting for results: 136 / 3472
# INFO:podpac.core.managers.parallel:(131.87348461151123) Finished result: 136 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.874000): Waiting for results: 137 / 3472
# INFO:podpac.core.managers.parallel:(131.8744843006134) Finished result: 137 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.875000): Waiting for results: 138 / 3472
# INFO:podpac.core.managers.parallel:(131.87648272514343) Finished result: 138 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.876000): Waiting for results: 139 / 3472
# INFO:podpac.core.managers.parallel:(131.87748265266418) Finished result: 139 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.878000): Waiting for results: 140 / 3472
# INFO:podpac.core.managers.parallel:(131.87848377227783) Finished result: 140 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.879000): Waiting for results: 141 / 3472
# INFO:podpac.core.managers.parallel:(131.88048124313354) Finished result: 141 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.880000): Waiting for results: 142 / 3472
# INFO:podpac.core.managers.parallel:(131.88148021697998) Finished result: 142 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.881000): Waiting for results: 143 / 3472
# INFO:podpac.core.managers.parallel:(131.8824806213379) Finished result: 143 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.883000): Waiting for results: 144 / 3472
# INFO:podpac.core.managers.parallel:(131.88447856903076) Finished result: 144 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.884000): Waiting for results: 145 / 3472
# INFO:podpac.core.managers.parallel:(131.88547825813293) Finished result: 145 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.886000): Waiting for results: 146 / 3472
# INFO:podpac.core.managers.parallel:(131.88747692108154) Finished result: 146 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.888000): Waiting for results: 147 / 3472
# INFO:podpac.core.managers.parallel:(131.8894760608673) Finished result: 147 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.889000): Waiting for results: 148 / 3472
# INFO:podpac.core.managers.parallel:(131.8904755115509) Finished result: 148 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.891000): Waiting for results: 149 / 3472
# INFO:podpac.core.managers.parallel:(131.89147472381592) Finished result: 149 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.892000): Waiting for results: 150 / 3472
# INFO:podpac.core.managers.parallel:(131.89347338676453) Finished result: 150 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.894000): Waiting for results: 151 / 3472
# INFO:podpac.core.managers.parallel:(131.8944730758667) Finished result: 151 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.895000): Waiting for results: 152 / 3472
# INFO:podpac.core.managers.parallel:(131.89647221565247) Finished result: 152 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.897000): Waiting for results: 153 / 3472
# INFO:podpac.core.managers.parallel:(131.89847111701965) Finished result: 153 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.898000): Waiting for results: 154 / 3472
# INFO:podpac.core.managers.parallel:(131.89947032928467) Finished result: 154 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.900000): Waiting for results: 155 / 3472
# INFO:podpac.core.managers.parallel:(131.90046954154968) Finished result: 155 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.901000): Waiting for results: 156 / 3472
# INFO:podpac.core.managers.parallel:(131.90246891975403) Finished result: 156 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.903000): Waiting for results: 157 / 3472
# INFO:podpac.core.managers.parallel:(131.90346789360046) Finished result: 157 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.904000): Waiting for results: 158 / 3472
# INFO:podpac.core.managers.parallel:(131.9054672718048) Finished result: 158 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.905000): Waiting for results: 159 / 3472
# INFO:podpac.core.managers.parallel:(131.9064657688141) Finished result: 159 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.907000): Waiting for results: 160 / 3472
# INFO:podpac.core.managers.parallel:(131.90746593475342) Finished result: 160 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.908000): Waiting for results: 161 / 3472
# INFO:podpac.core.managers.parallel:(131.90846586227417) Finished result: 161 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.909000): Waiting for results: 162 / 3472
# INFO:podpac.core.managers.parallel:(131.91046404838562) Finished result: 162 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.911000): Waiting for results: 163 / 3472
# INFO:podpac.core.managers.parallel:(131.91246247291565) Finished result: 163 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.912000): Waiting for results: 164 / 3472
# INFO:podpac.core.managers.parallel:(131.91346335411072) Finished result: 164 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.914000): Waiting for results: 165 / 3472
# INFO:podpac.core.managers.parallel:(131.91546177864075) Finished result: 165 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.915000): Waiting for results: 166 / 3472
# INFO:podpac.core.managers.parallel:(131.9164605140686) Finished result: 166 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.917000): Waiting for results: 167 / 3472
# INFO:podpac.core.managers.parallel:(131.91746020317078) Finished result: 167 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.918000): Waiting for results: 168 / 3472
# INFO:podpac.core.managers.parallel:(131.91945910453796) Finished result: 168 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.919000): Waiting for results: 169 / 3472
# INFO:podpac.core.managers.parallel:(131.9204580783844) Finished result: 169 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.920000): Waiting for results: 170 / 3472
# INFO:podpac.core.managers.parallel:(131.92145800590515) Finished result: 170 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.922000): Waiting for results: 171 / 3472
# WARNING:podpac.core.managers.parallel:(0:02:11.922000) 170 failed with exception Error in lambda function evaluation:
#
# Error Type: ValueError
# Error Message: Invalid definition for node 'podpac_version': 'node' property required
# Stack Trace:   File "/var/task/handler.py", line 268, in handler
#     node = Node.from_definition(pipeline["pipeline"])
#
#   File "/var/task/podpac/core/node.py", line 639, in from_definition
#     raise ValueError("Invalid definition for node '%s': 'node' property required" % name)
#
# INFO:podpac.core.managers.parallel:(131.92345690727234) Finished result: 171 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.924000): Waiting for results: 172 / 3472
# INFO:podpac.core.managers.parallel:(131.92445635795593) Finished result: 172 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.925000): Waiting for results: 173 / 3472
# INFO:podpac.core.managers.parallel:(131.92645502090454) Finished result: 173 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.926000): Waiting for results: 174 / 3472
# INFO:podpac.core.managers.parallel:(131.92745542526245) Finished result: 174 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.928000): Waiting for results: 175 / 3472
# INFO:podpac.core.managers.parallel:(131.92845487594604) Finished result: 175 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.929000): Waiting for results: 176 / 3472
# INFO:podpac.core.managers.parallel:(131.93045353889465) Finished result: 176 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.931000): Waiting for results: 177 / 3472
# INFO:podpac.core.managers.parallel:(131.93145203590393) Finished result: 177 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.932000): Waiting for results: 178 / 3472
# INFO:podpac.core.managers.parallel:(131.93245124816895) Finished result: 178 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.933000): Waiting for results: 179 / 3472
# INFO:podpac.core.managers.parallel:(131.9344503879547) Finished result: 179 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.934000): Waiting for results: 180 / 3472
# INFO:podpac.core.managers.parallel:(131.93545031547546) Finished result: 180 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.935000): Waiting for results: 181 / 3472
# INFO:podpac.core.managers.parallel:(131.93644881248474) Finished result: 181 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.937000): Waiting for results: 182 / 3472
# INFO:podpac.core.managers.parallel:(131.9384491443634) Finished result: 182 / 3472
# INFO:podpac.core.managers.parallel:(0:02:11.938000): Waiting for results: 183 / 3472
# ...
#
# INFO:podpac.core.managers.parallel:(132.1133496761322) Finished result: 258 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.113000): Waiting for results: 259 / 3472
# INFO:podpac.core.managers.parallel:(132.11434841156006) Finished result: 259 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.115000): Waiting for results: 260 / 3472
# WARNING:podpac.core.managers.parallel:(0:02:12.115000) 259 failed with exception Error in lambda function evaluation:
#
# Error Type: ValueError
# Error Message: Invalid definition for node 'podpac_version': 'node' property required
# Stack Trace:   File "/var/task/handler.py", line 268, in handler
#     node = Node.from_definition(pipeline["pipeline"])
#
#   File "/var/task/podpac/core/node.py", line 639, in from_definition
#     raise ValueError("Invalid definition for node '%s': 'node' property required" % name)
#
# INFO:podpac.core.managers.parallel:(132.1163477897644) Finished result: 260 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.116000): Waiting for results: 261 / 3472
# INFO:podpac.core.managers.parallel:(132.11734771728516) Finished result: 261 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.118000): Waiting for results: 262 / 3472
# INFO:podpac.core.managers.parallel:(132.1193459033966) Finished result: 262 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.119000): Waiting for results: 263 / 3472
# INFO:podpac.core.managers.parallel:(132.12134432792664) Finished result: 263 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.121000): Waiting for results: 264 / 3472
# INFO:podpac.core.managers.parallel:(132.12234377861023) Finished result: 264 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.123000): Waiting for results: 265 / 3472
# INFO:podpac.core.managers.parallel:(132.12334370613098) Finished result: 265 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.124000): Waiting for results: 266 / 3472
# INFO:podpac.core.managers.parallel:(132.12434315681458) Finished result: 266 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.125000): Waiting for results: 267 / 3472
# INFO:podpac.core.managers.parallel:(132.12634301185608) Finished result: 267 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.126000): Waiting for results: 268 / 3472
# INFO:podpac.core.managers.parallel:(132.12734150886536) Finished result: 268 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.127000): Waiting for results: 269 / 3472
# INFO:podpac.core.managers.parallel:(132.12834095954895) Finished result: 269 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.129000): Waiting for results: 270 / 3472
# INFO:podpac.core.managers.parallel:(132.12934112548828) Finished result: 270 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.130000): Waiting for results: 271 / 3472
# INFO:podpac.core.managers.parallel:(132.13133883476257) Finished result: 271 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.131000): Waiting for results: 272 / 3472
# INFO:podpac.core.managers.parallel:(132.132337808609) Finished result: 272 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.133000): Waiting for results: 273 / 3472
# INFO:podpac.core.managers.parallel:(132.13333773612976) Finished result: 273 / 3472
# INFO:podpac.core.managers.parallel:(0:02:12.134000): Waiting for results: 274 / 3472
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# INFO:podpac.core.managers.parallel:Submitting source 306
# INFO:podpac.core.managers.parallel:Submitting source 309
# INFO:podpac.core.managers.parallel:Submitting source 305
# INFO:podpac.core.managers.parallel:Submitting source 311
# INFO:podpac.core.managers.parallel:Submitting source 321
# INFO:podpac.core.managers.parallel:Submitting source 298
# INFO:podpac.core.managers.parallel:Submitting source 299
# INFO:podpac.core.managers.parallel:Submitting source 301
# INFO:podpac.core.managers.parallel:Submitting source 307
# INFO:podpac.core.managers.parallel:Submitting source 297
# INFO:podpac.core.managers.parallel:Submitting source 302
# INFO:podpac.core.managers.parallel:Submitting source 303
# INFO:podpac.core.managers.parallel:Submitting source 310
# INFO:podpac.core.managers.parallel:Submitting source 322
# INFO:podpac.core.managers.parallel:Submitting source 325
# INFO:podpac.core.managers.parallel:Submitting source 323
# INFO:podpac.core.managers.parallel:Submitting source 324
# INFO:podpac.core.managers.parallel:Submitting source 273
# INFO:podpac.core.managers.parallel:(141.1915683746338) Finished result: 274 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.204000): Waiting for results: 275 / 3472
# INFO:podpac.core.managers.parallel:(141.22452068328857) Finished result: 275 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.237000): Waiting for results: 276 / 3472
# INFO:podpac.core.managers.parallel:(141.24450206756592) Finished result: 276 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.247000): Waiting for results: 277 / 3472
# INFO:podpac.core.managers.parallel:(141.2485020160675) Finished result: 277 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.251000): Waiting for results: 278 / 3472
# INFO:podpac.core.managers.parallel:(141.25349688529968) Finished result: 278 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.258000): Waiting for results: 279 / 3472
# INFO:podpac.core.managers.parallel:(141.2594919204712) Finished result: 279 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.260000): Waiting for results: 280 / 3472
# INFO:podpac.core.managers.parallel:(141.26049160957336) Finished result: 280 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.261000): Waiting for results: 281 / 3472
# INFO:podpac.core.managers.parallel:(141.26249074935913) Finished result: 281 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.263000): Waiting for results: 282 / 3472
# INFO:podpac.core.managers.parallel:(141.26348996162415) Finished result: 282 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.264000): Waiting for results: 283 / 3472
# INFO:podpac.core.managers.parallel:(141.26548886299133) Finished result: 283 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.265000): Waiting for results: 284 / 3472
# INFO:podpac.core.managers.parallel:(141.2664885520935) Finished result: 284 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.267000): Waiting for results: 285 / 3472
# INFO:podpac.core.managers.parallel:(141.26848697662354) Finished result: 285 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.268000): Waiting for results: 286 / 3472
# INFO:podpac.core.managers.parallel:(141.2694869041443) Finished result: 286 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.270000): Waiting for results: 287 / 3472
# INFO:podpac.core.managers.parallel:(141.27148747444153) Finished result: 287 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.271000): Waiting for results: 288 / 3472
# INFO:podpac.core.managers.parallel:(141.2724847793579) Finished result: 288 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.273000): Waiting for results: 289 / 3472
# INFO:podpac.core.managers.parallel:(141.2734842300415) Finished result: 289 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.274000): Waiting for results: 290 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 289
# INFO:podpac.core.managers.parallel:(141.53333687782288) Finished result: 290 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.538000): Waiting for results: 291 / 3472
# INFO:podpac.core.managers.parallel:(141.5463354587555) Finished result: 291 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.547000): Waiting for results: 292 / 3472
# INFO:podpac.core.managers.parallel:(141.5473289489746) Finished result: 292 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.548000): Waiting for results: 293 / 3472
# INFO:podpac.core.managers.parallel:(141.54932928085327) Finished result: 293 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.551000): Waiting for results: 294 / 3472
# INFO:podpac.core.managers.parallel:(141.552325963974) Finished result: 294 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.555000): Waiting for results: 295 / 3472
# INFO:podpac.core.managers.parallel:(141.55632495880127) Finished result: 295 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.557000): Waiting for results: 296 / 3472
# INFO:podpac.core.managers.parallel:(141.55832266807556) Finished result: 296 / 3472
# INFO:podpac.core.managers.parallel:(0:02:21.558000): Waiting for results: 297 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 318
# INFO:podpac.core.managers.parallel:Submitting source 320
# INFO:podpac.core.managers.parallel:Submitting source 319
# INFO:podpac.core.managers.parallel:Submitting source 333
# INFO:podpac.core.managers.parallel:Submitting source 328
# INFO:podpac.core.managers.parallel:Submitting source 326
# INFO:podpac.core.managers.parallel:Submitting source 329
# INFO:podpac.core.managers.parallel:Submitting source 330
# INFO:podpac.core.managers.parallel:Submitting source 334
# INFO:podpac.core.managers.parallel:Submitting source 335
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# INFO:podpac.core.managers.parallel:Submitting source 345
# INFO:podpac.core.managers.parallel:Submitting source 346
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# INFO:podpac.core.managers.parallel:Submitting source 338
# INFO:podpac.core.managers.parallel:Submitting source 336
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# INFO:podpac.core.managers.parallel:Submitting source 344
# INFO:podpac.core.managers.parallel:Submitting source 349
# INFO:podpac.core.managers.parallel:Submitting source 332
# INFO:podpac.core.managers.parallel:Submitting source 296
# INFO:podpac.core.managers.parallel:Submitting source 327
# INFO:podpac.core.managers.parallel:Submitting source 331
# INFO:podpac.core.managers.parallel:(151.89031624794006) Finished result: 297 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.933000): Waiting for results: 298 / 3472
# INFO:podpac.core.managers.parallel:(151.93429136276245) Finished result: 298 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.937000): Waiting for results: 299 / 3472
# INFO:podpac.core.managers.parallel:(151.94928455352783) Finished result: 299 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.951000): Waiting for results: 300 / 3472
# INFO:podpac.core.managers.parallel:(151.95228147506714) Finished result: 300 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.952000): Waiting for results: 301 / 3472
# INFO:podpac.core.managers.parallel:(151.9572970867157) Finished result: 301 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.958000): Waiting for results: 302 / 3472
# INFO:podpac.core.managers.parallel:(151.95927739143372) Finished result: 302 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.959000): Waiting for results: 303 / 3472
# INFO:podpac.core.managers.parallel:(151.96027898788452) Finished result: 303 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.962000): Waiting for results: 304 / 3472
# INFO:podpac.core.managers.parallel:(151.96227526664734) Finished result: 304 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.963000): Waiting for results: 305 / 3472
# INFO:podpac.core.managers.parallel:(151.9642744064331) Finished result: 305 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.965000): Waiting for results: 306 / 3472
# INFO:podpac.core.managers.parallel:(151.96627402305603) Finished result: 306 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.966000): Waiting for results: 307 / 3472
# INFO:podpac.core.managers.parallel:(151.96727228164673) Finished result: 307 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.968000): Waiting for results: 308 / 3472
# INFO:podpac.core.managers.parallel:(151.96827387809753) Finished result: 308 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.969000): Waiting for results: 309 / 3472
# WARNING:podpac.core.managers.parallel:(0:02:31.970000) 308 failed with exception Error in lambda function evaluation:
#
# Error Type: ValueError
# Error Message: Invalid definition for node 'podpac_version': 'node' property required
# Stack Trace:   File "/var/task/handler.py", line 268, in handler
#     node = Node.from_definition(pipeline["pipeline"])
#
#   File "/var/task/podpac/core/node.py", line 639, in from_definition
#     raise ValueError("Invalid definition for node '%s': 'node' property required" % name)
#
# INFO:podpac.core.managers.parallel:(151.97127032279968) Finished result: 309 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.971000): Waiting for results: 310 / 3472
# INFO:podpac.core.managers.parallel:(151.97227811813354) Finished result: 310 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.973000): Waiting for results: 311 / 3472
# INFO:podpac.core.managers.parallel:(151.97427988052368) Finished result: 311 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.974000): Waiting for results: 312 / 3472
# INFO:podpac.core.managers.parallel:(151.9752697944641) Finished result: 312 / 3472
# INFO:podpac.core.managers.parallel:(0:02:31.976000): Waiting for results: 313 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 339
# INFO:podpac.core.managers.parallel:Submitting source 350
# INFO:podpac.core.managers.parallel:Submitting source 342
# INFO:podpac.core.managers.parallel:Submitting source 353
# INFO:podpac.core.managers.parallel:Submitting source 354
# INFO:podpac.core.managers.parallel:Submitting source 343
# INFO:podpac.core.managers.parallel:Submitting source 340
# INFO:podpac.core.managers.parallel:Submitting source 341
# INFO:podpac.core.managers.parallel:Submitting source 347
# INFO:podpac.core.managers.parallel:Submitting source 312
# INFO:podpac.core.managers.parallel:(157.4475486278534) Finished result: 313 / 3472
# INFO:podpac.core.managers.parallel:(0:02:37.483000): Waiting for results: 314 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 359
# INFO:podpac.core.managers.parallel:Submitting source 364
# INFO:podpac.core.managers.parallel:Submitting source 317
# INFO:podpac.core.managers.parallel:Submitting source 358
# INFO:podpac.core.managers.parallel:Submitting source 361
# INFO:podpac.core.managers.parallel:Submitting source 363
# INFO:podpac.core.managers.parallel:Submitting source 362
# INFO:podpac.core.managers.parallel:Submitting source 360
# INFO:podpac.core.managers.parallel:Submitting source 379
# INFO:podpac.core.managers.parallel:Submitting source 374
# INFO:podpac.core.managers.parallel:Submitting source 375
# INFO:podpac.core.managers.parallel:Submitting source 366
# INFO:podpac.core.managers.parallel:Submitting source 377
# INFO:podpac.core.managers.parallel:Submitting source 367
# INFO:podpac.core.managers.parallel:Submitting source 369
# INFO:podpac.core.managers.parallel:Submitting source 376
# INFO:podpac.core.managers.parallel:Submitting source 368
# INFO:podpac.core.managers.parallel:Submitting source 370
# INFO:podpac.core.managers.parallel:Submitting source 380
# INFO:podpac.core.managers.parallel:Submitting source 378
# INFO:podpac.core.managers.parallel:Submitting source 313
# INFO:podpac.core.managers.parallel:(166.59475135803223) Finished result: 314 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 316
# INFO:podpac.core.managers.parallel:Submitting source 355
# INFO:podpac.core.managers.parallel:Submitting source 357
# INFO:podpac.core.managers.parallel:(0:02:46.637000): Waiting for results: 315 / 3472
# INFO:podpac.core.managers.parallel:Submitting source 315
# INFO:podpac.core.managers.parallel:Submitting source 398
# INFO:podpac.core.managers.parallel:Submitting source 396
# INFO:podpac.core.managers.parallel:Submitting source 397
# INFO:podpac.core.managers.parallel:Submitting source 395
# INFO:podpac.core.managers.parallel:Submitting source 387
# ERROR:podpac.core.managers.aws:Unhandled error from lambda function
# INFO:podpac.core.managers.parallel:Submitting source 382
# INFO:podpac.core.managers.parallel:Submitting source 393
# INFO:podpac.core.managers.parallel:Submitting source 399
# INFO:podpac.core.managers.parallel:Submitting source 389
# INFO:podpac.core.managers.parallel:Submitting source 388
# INFO:podpac.core.managers.parallel:Submitting source 405
# INFO:podpac.core.managers.parallel:Submitting source 391

# %%
# Check the results
out_f = podpac.data.Zarr(
    source=DST_FILE,
)
out_f

# %%
d0 = cats.dataset['d0'][:6, :6, :]
